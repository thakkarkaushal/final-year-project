# %%
import cv2
import numpy as np

# Create our body classifier
body_classifier = cv2.CascadeClassifier('person1.xml')

# Initiate video capture for video file, here we are using the video file in which pedestrians would be detected
cap = cv2.VideoCapture('A1first.mp4')
density=0
listof=[]
# Loop once video is successfully loaded
while cap.isOpened():

    # Reading the each frame of the video 
    ret, frame = cap.read()
    if ret == False:
        break
  # here we are resizing the frame, to half of its size, we are doing to speed up the classification
 # as larger images have lot more windows to slide over, so in overall we reducing the resolution
#of video by half that’s what 0.5 indicate, and we are also using quicker interpolation method that is #interlinear
    frame = cv2.resize(frame, None,fx=0.5, fy=0.5, interpolation = cv2.INTER_LINEAR)

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # Pass frame to our body classifier
    bodies = body_classifier.detectMultiScale(gray, 1.2, 3)
    cv2.imshow('Pedestrians1', frame)
    # Extract bounding boxes for any bodies identified
    for (x,y,w,h) in bodies:
        
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 255), 2)
        cv2.imshow('Pedestrians', frame)
        print(str(x+w)+" "+str(y+h))
        yh=y+h
        xw=x+w
        if yh>100 and xw>100:
            if str(yh)+"_"+str(xw) not in listof:
                listof.append(str(yh)+"_"+str(xw))
                density+=1

    if cv2.waitKey(20) == 13: #13 is the Enter Key
        break

cap.release()
cv2.destroyAllWindows()
density=density-500
print("density of public calculated as "+str(len(listof)/15))
platformdensity=len(listof)/15
print("length is  "+str(len(listof)))
print(listof)
# Out:
# 136 111
# 265 71
# 136 111
# 266 73
# 266 73
# 136 111
# 135 111
# 265 71
# 136 111
# 264 70
# 137 113
# 264 70
# 126 98
# 137 113
# 264 70
# 126 98
# 137 114
# 264 70
# 126 98
# 137 114
# 265 71
# 128 98
# 265 70
# 138 113
# 265 71
# 130 98
# 137 113
# 137 113
# 265 69
# 130 98
# 136 113
# 265 71
# 136 112
# 266 73
# 136 112
# 267 73
# 136 113
# 267 74
# 136 113
# 266 74
# 135 113
# 266 72
# 266 73
# 136 113
# 136 113
# 267 74
# 137 114
# 266 73
# 138 113
# 266 72
# 139 114
# 266 72
# 130 97
# 139 114
# 266 72
# 266 71
# 127 97
# 138 113
# 135 111
# 267 70
# 136 111
# 268 71
# 136 111
# 268 71
# 136 111
# 268 73
# 136 111
# 268 72
# 136 110
# 268 72
# 136 111
# 268 72
# 268 71
# 136 111
# 267 72
# 136 111
# 268 72
# 136 111
# 136 111
# 268 72
# 266 71
# 137 111
# 266 71
# 136 111
# 136 110
# 267 71
# 136 110
# 268 72
# 135 111
# 267 72
# 135 111
# 267 72
# 135 110
# 267 71
# 135 110
# 267 70
# 136 110
# 267 70
# 136 110
# 267 71
# 267 72
# 136 110
# 135 110
# 267 70
# 137 109
# 266 68
# 266 68
# 138 110
# 266 68
# 138 110
# 266 68
# 138 111
# 137 110
# 265 68
# 136 110
# 265 68
# 265 68
# 138 111
# 136 110
# 265 68
# 266 70
# 138 110
# 266 69
# 137 109
# 136 110
# 266 70
# 135 110
# 266 69
# 134 111
# 266 70
# 137 111
# 266 69
# 266 68
# 137 111
# 137 111
# 266 68
# 135 110
# 266 68
# 136 110
# 265 68
# 265 69
# 137 109
# 265 69
# 136 110
# 265 68
# 136 111
# 265 68
# 137 111
# 137 111
# 265 68
# 135 110
# 265 68
# 136 110
# 265 70
# 136 110
# 266 68
# 138 110
# 266 68
# 137 109
# 266 68
# 137 109
# 266 70
# 136 110
# 265 68
# density of public calculated as 1.1333333333333333
# length is  17
# ['111_136', '111_135', '113_137', '114_137', '113_138', '113_136', '112_136', '113_135', '114_139', '110_136', '111_137', '110_135', '109_137', '110_138', '111_138', '110_137', '111_134']

# %%
import cv2
import numpy as np

# Create our body classifier
body_classifier = cv2.CascadeClassifier('bus.xml')

# Initiate video capture for video file, here we are using the video file in which pedestrians would be detected
cap = cv2.VideoCapture('A2first.mp4')
density=0
listof=[]
# Loop once video is successfully loaded
while cap.isOpened():

    # Reading the each frame of the video 
    ret, frame = cap.read()
    if ret == False:
        break
  # here we are resizing the frame, to half of its size, we are doing to speed up the classification
 # as larger images have lot more windows to slide over, so in overall we reducing the resolution
#of video by half that’s what 0.5 indicate, and we are also using quicker interpolation method that is #interlinear
    frame = cv2.resize(frame, None,fx=0.5, fy=0.5, interpolation = cv2.INTER_LINEAR)

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # Pass frame to our body classifier
    bodies = body_classifier.detectMultiScale(gray, 1.2, 3)
    cv2.imshow('Pedestrians1', frame)
    # Extract bounding boxes for any bodies identified
    for (x,y,w,h) in bodies:
        
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 255), 2)
        cv2.imshow('Pedestrians', frame)
        print(str(y+h)+" "+str(x+w))
        yh=y+h
        xw=x+w
        if yh>150 and xw>250:
            if str(yh)+"_"+str(xw) not in listof:
                listof.append(str(yh)+"_"+str(xw))
                density+=1

    if cv2.waitKey(20) == 13: #13 is the Enter Key
        break

cap.release()
cv2.destroyAllWindows()
density=density-500
print("density of public calculated as "+str(len(listof)/15))
print("length is  "+str(len(listof)))
busdensity=len(listof)/15
print(listof)
# Out:
# 207 353
# 76 297
# 89 92
# 210 353
# 89 91
# 211 352
# 89 91
# 207 355
# 88 92
# 234 212
# 154 357
# 213 354
# 72 293
# 89 93
# 235 214
# 153 184
# 205 356
# 88 92
# 151 184
# 205 355
# 89 93
# 79 299
# 156 188
# 207 355
# 77 300
# 89 93
# 156 188
# 207 355
# 89 93
# 206 355
# 89 93
# 235 214
# 206 356
# 88 93
# 206 357
# 88 93
# 206 355
# 89 93
# 207 356
# 87 92
# 235 214
# 207 356
# 233 211
# 87 92
# 205 356
# 87 92
# 76 298
# 152 186
# 208 355
# 87 92
# 153 184
# 207 353
# 70 290
# 88 91
# 207 354
# 88 91
# 206 354
# 89 92
# 152 182
# 209 355
# 88 92
# 152 185
# 210 354
# 88 93
# 214 354
# 88 94
# 211 356
# 87 94
# 214 357
# 76 298
# 87 96
# 212 357
# 90 98
# 77 304
# 156 190
# 214 357
# 91 97
# 79 304
# 210 359
# 77 300
# 92 97
# 216 354
# 90 95
# 78 300
# 213 354
# 90 94
# 154 357
# 202 357
# 76 298
# 89 93
# 204 356
# 89 93
# 90 93
# 195 360
# 90 92
# 195 360
# 205 356
# 89 92
# 153 184
# 212 354
# 87 92
# 215 355
# 90 94
# 209 357
# 90 95
# 216 356
# 90 95
# 216 357
# 91 96
# 218 355
# 63 106
# 94 96
# 213 356
# 93 97
# 80 300
# 221 355
# 93 96
# 216 353
# 94 94
# 84 300
# 157 358
# 220 352
# 93 94
# 155 184
# 209 354
# 92 91
# 218 349
# 93 91
# 77 293
# 200 358
# 216 351
# 92 91
# 195 359
# 209 353
# 91 90
# 203 356
# 92 91
# 216 353
# 92 92
# 75 289
# 212 356
# 92 93
# 216 355
# 91 93
# 218 355
# 95 97
# 222 355
# 94 97
# 118 66
# 159 190
# 219 357
# 118 66
# 95 99
# 161 190
# 221 356
# 95 98
# 81 299
# 159 188
# 218 355
# 118 66
# 95 98
# 81 298
# 216 356
# 61 105
# 95 97
# 213 356
# 94 96
# 220 353
# 93 95
# 210 356
# 93 94
# 218 351
# 92 93
# 211 354
# 93 93
# 206 355
# 95 92
# 207 355
# 92 90
# 211 355
# 94 92
# 213 355
# 93 93
# 160 359
# 216 356
# 64 106
# 92 93
# 215 357
# 93 96
# 220 357
# 93 99
# 118 66
# 221 358
# 62 108
# 94 99
# 123 76
# 220 358
# 93 101
# 124 77
# 160 195
# 220 358
# 125 77
# 94 101
# 166 96
# 160 195
# 220 358
# 125 78
# 94 101
# 166 96
# 160 195
# 220 358
# 125 78
# 93 101
# 160 195
# 221 358
# 125 78
# 94 101
# 160 195
# 221 358
# 63 109
# 126 78
# 94 101
# 221 357
# 124 74
# 96 101
# 215 357
# 62 108
# 97 100
# 95 98
# 207 357
# 95 95
# 159 359
# 97 92
# 162 357
# 203 355
# 214 349
# 94 89
# 162 356
# 196 357
# 202 351
# 91 85
# 159 353
# 202 351
# 92 85
# 157 350
# 217 344
# 197 355
# 92 85
# 159 352
# 203 352
# 90 85
# 159 353
# 205 353
# 64 100
# 92 87
# 209 354
# 92 90
# 162 357
# 216 353
# 94 93
# 215 358
# 95 96
# 218 356
# 62 108
# 118 67
# 95 99
# 218 358
# 95 100
# 122 77
# 219 356
# 96 100
# 217 357
# 96 100
# 220 356
# 95 98
# 208 357
# 93 95
# 204 357
# 94 95
# 203 355
# 92 92
# 204 356
# 162 357
# 92 91
# 205 354
# 89 90
# 159 356
# 207 356
# 89 90
# 161 357
# 210 350
# 91 91
# 198 358
# 158 356
# 210 354
# 91 93
# density of public calculated as 6.0
# length is  90
# ['207_353', '210_353', '211_352', '207_355', '154_357', '213_354', '205_356', '205_355', '206_355', '206_356', '206_357', '207_356', '208_355', '207_354', '206_354', '209_355', '210_354', '214_354', '211_356', '214_357', '212_357', '210_359', '216_354', '202_357', '204_356', '195_360', '212_354', '215_355', '209_357', '216_356', '216_357', '218_355', '213_356', '221_355', '216_353', '157_358', '220_352', '209_354', '218_349', '200_358', '216_351', '195_359', '209_353', '203_356', '212_356', '216_355', '222_355', '219_357', '221_356', '220_353', '210_356', '218_351', '211_354', '211_355', '213_355', '160_359', '215_357', '220_357', '221_358', '220_358', '221_357', '207_357', '159_359', '162_357', '203_355', '214_349', '162_356', '196_357', '202_351', '159_353', '157_350', '217_344', '197_355', '159_352', '203_352', '205_353', '215_358', '218_356', '218_358', '219_356', '217_357', '220_356', '208_357', '204_357', '205_354', '159_356', '161_357', '210_350', '198_358', '158_356']

# %%
print(busdensity)
print(platformdensity)
if busdensity>15 and platformdensity>15:
    print("rescheduling of bus might require")
else:
    print("rescheduling of bus not  required")
# Out:
# rescheduling of bus not  required
